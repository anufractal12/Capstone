# %%
dbutils.fs.mount(
   source="wasbs://airqualitycontainer@anuaqstorageacc.blob.core.windows.net",
   mount_point="/mnt/anuaqstorageacc",
   extra_configs={
       "fs.azure.account.key.anuaqstorageacc.blob.core.windows.net": dbutils.secrets.get(
           scope="AnuradhaADBScopeCapstone", key="anuradhasecret"
       )
   }
)
